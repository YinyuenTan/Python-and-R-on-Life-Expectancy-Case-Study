# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-750004fd-4ae5-4838-bc51-96112c1cdec1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-750004fd-4ae5-4838-bc51-96112c1cdec1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Life Expectancy.csv to Life Expectancy (3).csv

# %% [markdown]
# # Dependent Variable
# **Life Expectancy**: Life expectancy in age
#
# # Independent Variables
# **Status**: Developed / Developing Country
# **Adult Mortality**: Adult Mortality Rates of both sexes (probability of dying between 15 and 60 years per 1000 population)
# **infant deaths**: Number of Infant Deaths per 1000 population
# **Alcohol**: Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)
# **Percentage expenditure**: Expenditure on health as a percentage of Gross Domestic Product per capita (%)
# **Hepatitis B**: Hepatitis B immunization coverage among 1-year-olds (%)
# **Measles**: Measles - number of reported cases per 1000 population
# **BMI**: Average Body Mass Index of entire population
# **under-five deaths**: Number of under-five deaths per 1000 population
# **Polio**: Polio (Pol3) immunization coverage among 1-year-olds (%)
# **Total expenditure**: General government expenditure on health as a percentage of total government expenditure (%)
# **Diphtheria**: Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)
# **HIV/AIDS**: Deaths per 1 000 live births HIV/AIDS (0-4 years)
# **GDP**: Gross Domestic Product per capital (in USD)
# **Population**: Population of the country
# **thinness 1-19 years**: Prevalence of thinness among children and adolescents for Age 10 to 19 (%)
# **thinness 5-9 years**: Prevalence of thinness among children for Age 5 to 9(%)
# **Income composition of resources**: Human Development Index in terms of income composition of resources (index ranging from 0 to 1)
# **Schooling**: Number of years of Schooling(years)

# %%
import pandas as pd

import seaborn as sns
sns.set(rc = {'figure.figsize': (10,8)})
sns.set_style('whitegrid')

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Life Expectancy.csv')
df.shape
# Out:
# (2938, 22)

# %%
df.sample(10)
# Out:
#                                Country  ...  Schooling
# 831                        El Salvador  ...       11.8
# 1215                         Indonesia  ...       10.6
# 305   Bolivia (Plurinational State of)  ...       13.8
# 1899                           Nigeria  ...        9.3
# 2518                            Sweden  ...       15.9
# 2694                            Turkey  ...       11.5
# 880                            Estonia  ...       15.0
# 1669                         Mauritius  ...       14.7
# 750                            Denmark  ...       16.6
# 2530                       Switzerland  ...       15.2
#
# [10 rows x 22 columns]

# %%
df.describe(include = "all")
# Out:
#            Country         Year  ... Income composition of resources    Schooling
# count         2938  2938.000000  ...                     2771.000000  2775.000000
# unique         193          NaN  ...                             NaN          NaN
# top     Mauritania          NaN  ...                             NaN          NaN
# freq            16          NaN  ...                             NaN          NaN
# mean           NaN  2007.518720  ...                        0.627551    11.992793
# std            NaN     4.613841  ...                        0.210904     3.358920
# min            NaN  2000.000000  ...                        0.000000     0.000000
# 25%            NaN  2004.000000  ...                        0.493000    10.100000
# 50%            NaN  2008.000000  ...                        0.677000    12.300000
# 75%            NaN  2012.000000  ...                        0.779000    14.300000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
100*df.isnull().sum()/df.shape[0]
# Out:
# Country                             0.000000
# Year                                0.000000
# Status                              0.000000
# Life expectancy                     0.340368
# Adult Mortality                     0.340368
# infant deaths                       0.000000
# Alcohol                             6.603131
# percentage expenditure              0.000000
# Hepatitis B                        18.822328
# Measles                             0.000000
# BMI                                 1.157250
# under-five deaths                   0.000000
# Polio                               0.646698
# Total expenditure                   7.692308
# Diphtheria                          0.646698
# HIV/AIDS                            0.000000
# GDP                                15.248468
# Population                         22.191967
# thinness  1-19 years                1.157250
# thinness 5-9 years                  1.157250
# Income composition of resources     5.684139
# ...

# %%
#Drop rows with Na values
df = df.dropna()

#Interpolation to fill Na values
#for col in df.columns:
  #df[col] = df[col].interpolate(method='linear',limit_direction='both')

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
# BMI                                0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
# HIV/AIDS                           0
# GDP                                0
# Population                         0
# thinness  1-19 years               0
# thinness 5-9 years                 0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1649 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1649 non-null   object
#  1   Year                             1649 non-null   int64
#  2   Status                           1649 non-null   object
#  3   Life expectancy                  1649 non-null   float64
#  4   Adult Mortality                  1649 non-null   float64
#  5   infant deaths                    1649 non-null   int64
#  6   Alcohol                          1649 non-null   float64
#  7   percentage expenditure           1649 non-null   float64
#  8   Hepatitis B                      1649 non-null   float64
#  9   Measles                          1649 non-null   int64
#  10  BMI                              1649 non-null   float64
#  11  under-five deaths                1649 non-null   int64
# ...

# %%
df.describe(include = "all")
# Out:
#         Country         Year  ... Income composition of resources    Schooling
# count      1649  1649.000000  ...                     1649.000000  1649.000000
# unique      133          NaN  ...                             NaN          NaN
# top     Albania          NaN  ...                             NaN          NaN
# freq         16          NaN  ...                             NaN          NaN
# mean        NaN  2007.840509  ...                        0.631551    12.119891
# std         NaN     4.087711  ...                        0.183089     2.795388
# min         NaN  2000.000000  ...                        0.000000     4.200000
# 25%         NaN  2005.000000  ...                        0.509000    10.300000
# 50%         NaN  2008.000000  ...                        0.673000    12.300000
# 75%         NaN  2011.000000  ...                        0.751000    14.000000
# max         NaN  2015.000000  ...                        0.936000    20.700000
#
# [11 rows x 22 columns]

# %%
df.corr()
# Out:
#                                      Year  ...  Schooling
# Year                             1.000000  ...   0.088732
# Life expectancy                  0.050771  ...   0.727630
# Adult Mortality                 -0.037092  ...  -0.421171
# infant deaths                    0.008029  ...  -0.214372
# Alcohol                         -0.113365  ...   0.616975
# percentage expenditure           0.069553  ...   0.422088
# Hepatitis B                      0.114897  ...   0.215182
# Measles                         -0.053822  ...  -0.115660
# BMI                              0.005739  ...   0.554844
# under-five deaths                0.010479  ...  -0.226013
# Polio                           -0.016699  ...   0.350147
# Total expenditure                0.059493  ...   0.243783
# Diphtheria                       0.029641  ...   0.350398
# HIV/AIDS                        -0.123405  ...  -0.211840
# GDP                              0.096421  ...   0.467947
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr('pearson'), cmap = 'PuOr', fmt = '.2f', annot = True, vmin = -1, vmax = 1, center = 0);

# %%
df.corr()['Life expectancy'].sort_values(ascending=False)
# Out:
# Life expectancy                    1.000000
# Schooling                          0.727630
# Income composition of resources    0.721083
# BMI                                0.542042
# GDP                                0.441322
# percentage expenditure             0.409631
# Alcohol                            0.402718
# Diphtheria                         0.341331
# Polio                              0.327294
# Hepatitis B                        0.199935
# Total expenditure                  0.174718
# Year                               0.050771
# Population                        -0.022305
# Measles                           -0.068881
# infant deaths                     -0.169074
# under-five deaths                 -0.192265
# thinness 5-9 years                -0.457508
# thinness  1-19 years              -0.457838
# HIV/AIDS                          -0.592236
# Adult Mortality                   -0.702523
# Name: Life expectancy, dtype: float64

# %%
df.corr()['Life expectancy'].sort_values(ascending=False).plot(kind='bar');

# %%
from sklearn.linear_model import LinearRegression as LR

# %%
model = LR()

# %%
#Simple Linear Regression, Model 1
y = df['Life expectancy']
X = df[['Schooling']]

# %%
#Replace NaN Value
#X = X.fillna(X.mean(), inplace=True)
#y = y.fillna(y.mean(), inplace=True)

# %%
model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(f"R^2 = {model.score(X,y)}")
print(f"Intercept = {model.intercept_}")
print(f"Coefficients = {model.coef_}")
# Out:
# R^2 = 0.5294454639356108
# Intercept = 41.5503417453634
# Coefficients = [2.28978652]

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(X, y,color='b')
plt.plot(X, model.predict(X),color='k')
plt.xlabel("Schooling")
plt.ylabel("Life Expectancy")
plt.show()

# %%
#Multiple Linear Regression, Model 2
#The number of cases of most vaccine-preventable diseases is at an all-time low; hospitalizations and deaths have also shown striking decreases.
y2 = df['Life expectancy']
X2 = df[['Schooling', 'Hepatitis B', 'Diphtheria',  'Polio', 'Measles', 'HIV/AIDS']]

# %%
model.fit(X2, y2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(f"R^2 = {model.score(X2,y2)}")
print(f"Intercept = {model.intercept_}")
print(f"Coefficients = {model.coef_}")
# Out:
# R^2 = 0.7368398792078825
# Intercept = 44.87578424725493
# Coefficients = [ 1.88465451e+00 -1.15627468e-02  3.01787360e-02  1.52802192e-02
#   1.02609345e-06 -6.64448644e-01]

# %%
#Multiple Linear Regression, Model 3
#Low risk life style increases life expectancy
y3 = df['Life expectancy']
X3 = df[['Schooling', 'Hepatitis B', 'Diphtheria',  'Polio', 'Measles', 'HIV/AIDS', 'BMI', 'Alcohol','percentage expenditure']]

# %%
model.fit(X3, y3)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(f"R^2 = {model.score(X3,y3)}")
print(f"Intercept = {model.intercept_}")
print(f"Coefficients = {model.coef_}")
# Out:
# R^2 = 0.7640736793047787
# Intercept = 45.9588556910422
# Coefficients = [ 1.55388746e+00 -9.66648157e-03  3.14583993e-02  1.61839315e-02
#   1.60598438e-05 -6.34128564e-01  6.50781541e-02 -9.52277509e-02
#   6.42534528e-04]

# %%
X3.mean()
# Out:
# Schooling                   12.119891
# Hepatitis B                 79.217708
# Diphtheria                  84.155246
# Polio                       83.564585
# Measles                   2224.494239
# HIV/AIDS                     1.983869
# BMI                         38.128623
# Alcohol                      4.533196
# percentage expenditure     698.973558
# dtype: float64

# %%
X3.mode()
# Out:
#    Schooling  Hepatitis B  Diphtheria  ...   BMI  Alcohol  percentage expenditure
# 0       12.9         98.0        99.0  ...  55.7     0.01                     0.0
# 1        NaN          NaN         NaN  ...  57.0      NaN                     NaN
# 2        NaN          NaN         NaN  ...  57.2      NaN                     NaN
# 3        NaN          NaN         NaN  ...  58.5      NaN                     NaN
#
# [4 rows x 9 columns]

# %%
X3.median()
# Out:
# Schooling                  12.300000
# Hepatitis B                89.000000
# Diphtheria                 92.000000
# Polio                      93.000000
# Measles                    15.000000
# HIV/AIDS                    0.100000
# BMI                        43.700000
# Alcohol                     3.790000
# percentage expenditure    145.102253
# dtype: float64
